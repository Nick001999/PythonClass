# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
flights_data = pd.read_csv('/Users/nikolaykarabakin/Desktop/flight.csv')

# %%
flights_data.shape
# Out:
# (336776, 21)

# %%
flights_data.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
features = ["month", "origin", "arr_delay"]
data = flights_data[features]

# %%
data = pd.get_dummies(data, columns = ["origin", "month"])

# %%
data.head()
# Out:
#    arr_delay  origin_EWR  origin_JFK  origin_LGA  month_1  month_2  month_3  \
# 0       11.0        True       False       False     True    False    False
# 1       20.0       False       False        True     True    False    False
# 2       33.0       False        True       False     True    False    False
# 3      -18.0       False        True       False     True    False    False
# 4      -25.0       False       False        True     True    False    False
#
#    month_4  month_5  month_6  month_7  month_8  month_9  month_10  month_11  \
# 0    False    False    False    False    False    False     False     False
# 1    False    False    False    False    False    False     False     False
# 2    False    False    False    False    False    False     False     False
# 3    False    False    False    False    False    False     False     False
# 4    False    False    False    False    False    False     False     False
#
#    month_12
# 0     False
# 1     False
# ...

# %%
data["delayed"] = (data["dep_delay"] > 0).astype(int)
data.drop("dep_delay", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dep_delay'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...

# %%
data["delayed"] = (data["arr_delay"] > 0).astype(int)
data.drop("arr_delay", axis=1, inplace=True)

# %%
data["delayed"] = (data["dep_delay"] > 0).astype(int)
data.drop("dep_delay", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dep_delay'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...

# %%
data.head()
# Out:
#    origin_EWR  origin_JFK  origin_LGA  month_1  month_2  month_3  month_4  \
# 0        True       False       False     True    False    False    False
# 1       False       False        True     True    False    False    False
# 2       False        True       False     True    False    False    False
# 3       False        True       False     True    False    False    False
# 4       False       False        True     True    False    False    False
#
#    month_5  month_6  month_7  month_8  month_9  month_10  month_11  month_12  \
# 0    False    False    False    False    False     False     False     False
# 1    False    False    False    False    False     False     False     False
# 2    False    False    False    False    False     False     False     False
# 3    False    False    False    False    False     False     False     False
# 4    False    False    False    False    False     False     False     False
#
#    delayed
# 0        1
# 1        1
# 2        1
# ...

# %%
X = data.drop("delayed", axis=1)
y = data["delayed"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=80)

# %%
model = RandomForestClassifier(random_state=80)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=80)

# %%
prediction = model.predict(X_test)

accuracy = accuracy_score(y_test, prediction)

# %%
print(f"Accuracy of the model: {accuracy:.1%}")
# Out:
# Accuracy of the model: 60.9%
